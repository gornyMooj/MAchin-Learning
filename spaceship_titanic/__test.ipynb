# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
  
# Initialize data to lists.
data = [{'a': 1, 'b': 2, 'c': 3},
        {'a': 10, 'b': 20, 'c': 30}]
  
# Creates DataFrame.
df = pd.DataFrame(data)
  
# Print the data
df
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30

# %%
data = [{
        'd': 4,
        'f': ','.join(['Transported', 'HomePlanet', 'CryoSleep', 'RoomService']),
        'a': 7.2},
    {
        'd': 4,
        'f': ','.join(['Transported', 'HomePlanet', 'CryoSleep', 'FoodCourt']),
        'a': 7.2
    }]

# Creates DataFrame.
df = pd.DataFrame(data)
  
# Print the data
df
# Out:
#    d                                             f    a
# 0  4  Transported,HomePlanet,CryoSleep,RoomService  7.2
# 1  4    Transported,HomePlanet,CryoSleep,FoodCourt  7.2

# %%
import os
# prepering directories
path = os.getcwd()
# subfolders
input_dir = os.path.join(path, 'data')
output_dir = os.path.join(path, 'outputs')

# %%
test = pd.read_csv(os.path.join(input_dir, 'test.csv'))
train = pd.read_csv(os.path.join(input_dir, 'train.csv'))

# %%
# initializing new data frame that will be displayed in the table
dataset = test.copy()
data_review = pd.DataFrame(columns = ['Column','Data Type','Misssing Values', 'Missing Values [%]', 'Sum Unique Val'])



# looping via columns and extracting needed information
for index, column in enumerate(dataset.columns):
    data_type = dataset.dtypes[column]
    missing_value = dataset[column].isnull().sum()
    percentage = round((missing_value/len(dataset))* 100,1) if (missing_value/len(dataset))* 100 else 0
    unique_val = len(dataset[column].unique())
    data_review.loc[index] = [column, data_type, missing_value,percentage,unique_val]
    
pd.set_option("max_rows", None) # all rows are shown when printing  

    
data_review = data_review.sort_values(by=['Missing Values [%]'], ascending=False)
data_review.style\
        .bar(subset=["Misssing Values"], color='pink')\
        .bar(subset=["Sum Unique Val"], color='pink')\
# Out:
# <style type="text/css">
# #T_d6843_row0_col2, #T_d6843_row12_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 100.0%, transparent 100.0%);
# }
# #T_d6843_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 21.1%, transparent 21.1%);
# }
# #T_d6843_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 95.3%, transparent 95.3%);
# }
# #T_d6843_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 19.4%, transparent 19.4%);
# }
# #T_d6843_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 94.3%, transparent 94.3%);
# }
# #T_d6843_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 76.3%, transparent 76.3%);
# }
# #T_d6843_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 92.5%, transparent 92.5%);
# }
# #T_d6843_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 16.7%, transparent 16.7%);
# }
# #T_d6843_row4_col2, #T_d6843_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 87.7%, transparent 87.7%);
# }
# #T_d6843_row4_col4, #T_d6843_row6_col4, #T_d6843_row12_col2 {
#   width: 10em;
#   height: 80%;
# }
# #T_d6843_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 86.8%, transparent 86.8%);
# }
# #T_d6843_row5_col4, #T_d6843_row9_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 0.0%, transparent 0.0%);
# }
# #T_d6843_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 88.7%, transparent 88.7%);
# }
# #T_d6843_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 97.7%, transparent 97.7%);
# }
# #T_d6843_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 85.8%, transparent 85.8%);
# }
# #T_d6843_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 1.8%, transparent 1.8%);
# }
# #T_d6843_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 82.1%, transparent 82.1%);
# }
# #T_d6843_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 77.4%, transparent 77.4%);
# }
# #T_d6843_row10_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 19.7%, transparent 19.7%);
# }
# #T_d6843_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 75.5%, transparent 75.5%);
# }
# #T_d6843_row11_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 18.6%, transparent 18.6%);
# }
# </style>
# <table id="T_d6843_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Column</th>
#       <th class="col_heading level0 col1" >Data Type</th>
#       <th class="col_heading level0 col2" >Misssing Values</th>
#       <th class="col_heading level0 col3" >Missing Values [%]</th>
#       <th class="col_heading level0 col4" >Sum Unique Val</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6843_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_d6843_row0_col0" class="data row0 col0" >FoodCourt</td>
#       <td id="T_d6843_row0_col1" class="data row0 col1" >float64</td>
#       <td id="T_d6843_row0_col2" class="data row0 col2" >106</td>
#       <td id="T_d6843_row0_col3" class="data row0 col3" >2.500000</td>
#       <td id="T_d6843_row0_col4" class="data row0 col4" >903</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_d6843_row1_col0" class="data row1 col0" >Spa</td>
#       <td id="T_d6843_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_d6843_row1_col2" class="data row1 col2" >101</td>
#       <td id="T_d6843_row1_col3" class="data row1 col3" >2.400000</td>
#       <td id="T_d6843_row1_col4" class="data row1 col4" >834</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d6843_row2_col0" class="data row2 col0" >Cabin</td>
#       <td id="T_d6843_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_d6843_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_d6843_row2_col3" class="data row2 col3" >2.300000</td>
#       <td id="T_d6843_row2_col4" class="data row2 col4" >3266</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_d6843_row3_col0" class="data row3 col0" >ShoppingMall</td>
#       <td id="T_d6843_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_d6843_row3_col2" class="data row3 col2" >98</td>
#       <td id="T_d6843_row3_col3" class="data row3 col3" >2.300000</td>
#       <td id="T_d6843_row3_col4" class="data row3 col4" >716</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_d6843_row4_col0" class="data row4 col0" >CryoSleep</td>
#       <td id="T_d6843_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_d6843_row4_col2" class="data row4 col2" >93</td>
#       <td id="T_d6843_row4_col3" class="data row4 col3" >2.200000</td>
#       <td id="T_d6843_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_d6843_row5_col0" class="data row5 col0" >Destination</td>
#       <td id="T_d6843_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_d6843_row5_col2" class="data row5 col2" >92</td>
#       <td id="T_d6843_row5_col3" class="data row5 col3" >2.200000</td>
#       <td id="T_d6843_row5_col4" class="data row5 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d6843_row6_col0" class="data row6 col0" >VIP</td>
#       <td id="T_d6843_row6_col1" class="data row6 col1" >object</td>
#       <td id="T_d6843_row6_col2" class="data row6 col2" >93</td>
#       <td id="T_d6843_row6_col3" class="data row6 col3" >2.200000</td>
#       <td id="T_d6843_row6_col4" class="data row6 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row7" class="row_heading level0 row7" >12</th>
#       <td id="T_d6843_row7_col0" class="data row7 col0" >Name</td>
#       <td id="T_d6843_row7_col1" class="data row7 col1" >object</td>
#       <td id="T_d6843_row7_col2" class="data row7 col2" >94</td>
#       <td id="T_d6843_row7_col3" class="data row7 col3" >2.200000</td>
#       <td id="T_d6843_row7_col4" class="data row7 col4" >4177</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_d6843_row8_col0" class="data row8 col0" >Age</td>
#       <td id="T_d6843_row8_col1" class="data row8 col1" >float64</td>
#       <td id="T_d6843_row8_col2" class="data row8 col2" >91</td>
#       <td id="T_d6843_row8_col3" class="data row8 col3" >2.100000</td>
#       <td id="T_d6843_row8_col4" class="data row8 col4" >80</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_d6843_row9_col0" class="data row9 col0" >HomePlanet</td>
#       <td id="T_d6843_row9_col1" class="data row9 col1" >object</td>
#       <td id="T_d6843_row9_col2" class="data row9 col2" >87</td>
#       <td id="T_d6843_row9_col3" class="data row9 col3" >2.000000</td>
#       <td id="T_d6843_row9_col4" class="data row9 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row10" class="row_heading level0 row10" >7</th>
#       <td id="T_d6843_row10_col0" class="data row10 col0" >RoomService</td>
#       <td id="T_d6843_row10_col1" class="data row10 col1" >float64</td>
#       <td id="T_d6843_row10_col2" class="data row10 col2" >82</td>
#       <td id="T_d6843_row10_col3" class="data row10 col3" >1.900000</td>
#       <td id="T_d6843_row10_col4" class="data row10 col4" >843</td>
#     </tr>
#     <tr>
#       <th id="T_d6843_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d6843_row11_col0" class="data row11 col0" >VRDeck</td>

# %%
fig, ax = plt.subplots(figsize=(18, 8))
print(train.isnull().sum())
sns.heatmap(train.isnull())
print(train.info())
# Out:
# PassengerId       0
# HomePlanet      201
# CryoSleep       217
# Cabin           199
# Destination     182
# Age             179
# VIP             203
# RoomService     181
# FoodCourt       183
# ShoppingMall    208
# Spa             183
# VRDeck          188
# Name            200
# Transported       0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB
# None

# %%
# https://www.kaggle.com/code/viktortaran/space-titanic

# %%
################################################################################################################
### Let's fill in missing cost with "0" if a passenger was in CryoSleep. If you sleep you don't spend money. ###
################################################################################################################
